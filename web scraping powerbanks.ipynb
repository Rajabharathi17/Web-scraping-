# %% [markdown]
# # WEB SCRAPING

# %% [markdown]
# # importing libraries

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # scrabing a website

# %%
url="https://www.flipkart.com/mobile-accessories/power-banks/pr?sid=tyy,4mr,fu6&otracker=categorytree&otracker=nmenu_sub_Electronics_0_Power%20Banks"

# %%
url
# Out:
# 'https://www.flipkart.com/mobile-accessories/power-banks/pr?sid=tyy,4mr,fu6&otracker=categorytree&otracker=nmenu_sub_Electronics_0_Power%20Banks'

# %% [markdown]
# # website response

# %%
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %% [markdown]
# # parsing

# %%
soup=BeautifulSoup(res.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # to select a particular portion

# %%
products=soup.select('.s1Q9rs')

# %%
products
# Out:
# [<a class="s1Q9rs" href="/spigen-10000-mah-wireless-power-bank-20-w-fast-charging/p/itmb7acf2b09bc0c?pid=PWBG9EZEHX343QQJ&amp;lid=LSTPWBG9EZEHX343QQJ3BK1VA&amp;marketplace=FLIPKART&amp;store=tyy%2F4mr%2Ffu6&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=en_2ElDJBVZD7S9dj%2Bn8g64r5YHQeVEzPFl3Mq1YrVgcF6lzJT4IbkmYr%2FOdZonrIDpweL2dQS5pSNDZe9KNjXRAQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=d8h8euqta80000001655463932226" rel="noopener noreferrer" target="_blank" title="Spigen 10000 mAh Wireless Power Bank (20 W, Fast Charging)">Spigen 10000 mAh Wireless Power Bank (20 W, Fast Chargi...</a>,
# ...

# %%
products_title=[]
products_color=[]

# %%
for item in products:
    products_title.append(item.text)
    color="https://flipkart.com"+item['href']
    products_color.append(color)

# %%
products_title
# Out:
# ['Spigen 10000 mAh Wireless Power Bank (20 W, Fast Chargi...',
#  'ERD 10000 mAh Power Bank (Power Delivery 2.0)',
#  'conekt 10000 mAh Power Bank (12 W, Fast Charging)',
#  'Ambrane 10000 mAh Power Bank (12 W, Fast Charging)',
#  'Mi 3i 10000 mAh Power Bank (Fast Charging, 18W)',
#  'Mi 3i 10000 mAh Power Bank (Fast Charging, 18W)',
#  'Mi 3i 20000 mAh Power Bank (Fast Charging, 18W)',
#  'Callmate 10000 mAh Power Bank (15 W, Fast Charging)',
#  'Ambrane 10000 mAh Power Bank (12 W, Fast Charging)',
#  'realme 20000 mAh Power Bank (18 W, Quick Charge 2.0)',
#  'Mi 30000 mAh Power Bank (18 W, Fast Charging, Power Del...',
#  'SWISS MILITARY 10000 mAh Wireless Power Bank (18 W, Fas...',
#  'Ambrane 20000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Syska 10000 mAh Power Bank',
#  'realme 20000 mAh Power Bank (18 W, Quick Charge 2.0)',
#  'SWISS MILITARY 10000 mAh Wireless Power Bank (Fast Char...',
#  'Ambrane 20000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
# ...

# %%
products_color
# Out:
# ['https://flipkart.com/spigen-10000-mah-wireless-power-bank-20-w-fast-charging/p/itmb7acf2b09bc0c?pid=PWBG9EZEHX343QQJ&lid=LSTPWBG9EZEHX343QQJ3BK1VA&marketplace=FLIPKART&store=tyy%2F4mr%2Ffu6&srno=b_1_1&otracker=browse&fm=organic&iid=en_2ElDJBVZD7S9dj%2Bn8g64r5YHQeVEzPFl3Mq1YrVgcF6lzJT4IbkmYr%2FOdZonrIDpweL2dQS5pSNDZe9KNjXRAQ%3D%3D&ppt=None&ppn=None&ssid=d8h8euqta80000001655463932226',
#  'https://flipkart.com/erd-10000-mah-power-bank-power-delivery-2-0/p/itmfa1c275af125f?pid=PWBG88MDG837HHFU&lid=LSTPWBG88MDG837HHFUGXX6E0&marketplace=FLIPKART&store=tyy%2F4mr%2Ffu6&srno=b_1_2&otracker=browse&fm=organic&iid=en_2ElDJBVZD7S9dj%2Bn8g64r5YHQeVEzPFl3Mq1YrVgcF6K5usWy4OG%2BYv4osZhQuUcQNaMyDqsfTBKDm79ObMOkw%3D%3D&ppt=None&ppn=None&ssid=d8h8euqta80000001655463932226',
# ...

# %%
price=soup.select('._30jeq3')

# %%
price
# Out:
# [<div class="_30jeq3">₹2,399</div>,
#  <div class="_30jeq3">₹1,748</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹599</div>,
#  <div class="_30jeq3">₹1,099</div>,
#  <div class="_30jeq3">₹1,099</div>,
#  <div class="_30jeq3">₹1,899</div>,
#  <div class="_30jeq3">₹664</div>,
#  <div class="_30jeq3">₹599</div>,
#  <div class="_30jeq3">₹1,799</div>,
#  <div class="_30jeq3">₹2,499</div>,
#  <div class="_30jeq3">₹899</div>,
#  <div class="_30jeq3">₹1,299</div>,
#  <div class="_30jeq3">₹749</div>,
#  <div class="_30jeq3">₹1,799</div>,
#  <div class="_30jeq3">₹1,049</div>,
#  <div class="_30jeq3">₹1,299</div>,
#  <div class="_30jeq3">₹1,199</div>,
#  <div class="_30jeq3">₹1,499</div>,
#  <div class="_30jeq3">₹599</div>,
#  <div class="_30jeq3">₹999</div>,
#  <div class="_30jeq3">₹999</div>,
#  <div class="_30jeq3">₹649</div>,
#  <div class="_30jeq3">₹599</div>,
#  <div class="_30jeq3">₹1,699</div>,
#  <div class="_30jeq3">₹629</div>,
#  <div class="_30jeq3">₹599</div>,
# ...

# %% [markdown]
# # product price

# %%
products_price=[]

# %%
for items in price:
    products_price.append(item.text)

# %%
products_price
# Out:
# ['Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
#  'Ambrane 10000 mAh Power Bank (20 W, Quick Charge 3.0, P...',
# ...

# %% [markdown]
# # products rating

# %%
rating=soup.select('._3LWZlK')

# %%
rating
# Out:
# [<div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _32lA32">2.8<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.8<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
# ...

# %% [markdown]
# # product name

# %%
import pandas as pd

# %%
df=pd.DataFrame(products_title,columns=["products name"])

# %%
df
# Out:
#                                         products name
# 0   Spigen 10000 mAh Wireless Power Bank (20 W, Fa...
# 1       ERD 10000 mAh Power Bank (Power Delivery 2.0)
# 2   conekt 10000 mAh Power Bank (12 W, Fast Charging)
# 3   Ambrane 10000 mAh Power Bank (12 W, Fast Charg...
# 4     Mi 3i 10000 mAh Power Bank (Fast Charging, 18W)
# 5     Mi 3i 10000 mAh Power Bank (Fast Charging, 18W)
# 6     Mi 3i 20000 mAh Power Bank (Fast Charging, 18W)
# 7   Callmate 10000 mAh Power Bank (15 W, Fast Char...
# 8   Ambrane 10000 mAh Power Bank (12 W, Fast Charg...
# 9   realme 20000 mAh Power Bank (18 W, Quick Charg...
# 10  Mi 30000 mAh Power Bank (18 W, Fast Charging, ...
# 11  SWISS MILITARY 10000 mAh Wireless Power Bank (...
# 12  Ambrane 20000 mAh Power Bank (20 W, Quick Char...
# 13                         Syska 10000 mAh Power Bank
# 14  realme 20000 mAh Power Bank (18 W, Quick Charg...
# 15  SWISS MILITARY 10000 mAh Wireless Power Bank (...
# ...

# %% [markdown]
# # checking the data type

# %%
type(df.loc[0,'products name'])
# Out:
# str

# %%
import numpy as np

# %% [markdown]
# # saving the file

# %%
df.to_csv('powerbanks.csv')
